# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('example/bike.csv')

# %%
df.head(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000       3          13     16
# ...

# %%
# 단순임의 추출
df.sample(n=2, random_state = 34)
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 4219  2011-10-07 20:00:00       4        0           1        1  22.14
# 1409  2011-04-04 14:00:00       2        0           1        2  30.34
#
#        atemp  humidity  windspeed  casual  registered  count
# 4219  25.760        49     0.0000      30         167    197
# 1409  32.575        27    32.9975      47          76    123

# %%
print(df['season'].unique())
print(len(df['season'].unique()))
print(df['season'].nunique())
# 층화 표본추출
df.groupby('season').sample(n=3, random_state=1)
# Out:
# [1 2 3 4]
# 4
# 4
#                   datetime  season  holiday  workingday  weather   temp  \
# 791    2011-02-16 10:00:00       1        0           1        1  10.66
# 220    2011-01-10 11:00:00       1        0           1        2   6.56
# 224    2011-01-10 15:00:00       1        0           1        2   8.20
# 2086   2011-05-13 20:00:00       2        0           1        2  21.32
# 1439   2011-04-05 20:00:00       2        0           1        1  13.94
# 2239   2011-06-01 05:00:00       2        0           1        2  27.06
# 2726   2011-07-02 12:00:00       3        0           0        1  33.62
# 8549   2012-07-17 14:00:00       3        0           1        1  38.54
# 9318   2012-09-11 15:00:00       3        0           1        1  28.70
# 4545   2011-11-02 11:00:00       4        0           1        1  17.22
# 10325  2012-11-15 15:00:00       4        0           1        2  15.58
# 4719   2011-11-09 17:00:00       4        0           1        1  18.86
#
# ...

# %%
df.sample(frac=0.001, random_state=1)
len(df.sample(frac=0.001))
df.sample(frac=0.01).shape[0]
# Out:
# 134

# %%
df_train, df_test = train_test_split(df, train_size=0.7, random_state=123)
df_test
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 6495  2012-03-07 21:00:00       1        0           1        1  18.04
# 7050  2012-04-12 03:00:00       2        0           1        1  13.12
# 558   2011-02-06 10:00:00       1        0           0        1  12.30
# 5085  2011-12-05 23:00:00       4        0           1        2  18.86
# 3328  2011-08-08 14:00:00       3        0           1        1  33.62
# ...                   ...     ...      ...         ...      ...    ...
# 3733  2011-09-06 12:00:00       3        0           1        3  22.14
# 24    2011-01-02 00:00:00       1        0           0        2  18.86
# 9650  2012-10-06 11:00:00       4        0           0        1  26.24
# 6246  2012-02-16 12:00:00       1        0           1        3  13.12
# 5239  2011-12-12 09:00:00       4        0           1        2   7.38
#
#        atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.groupby('season').sample(frac=0.05)
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 374    2011-01-17 02:00:00       1        1           0        2   7.38
# 282    2011-01-13 05:00:00       1        0           1        1   5.74
# 64     2011-01-03 19:00:00       1        0           1        1   8.20
# 6712   2012-03-16 23:00:00       1        0           1        2  18.04
# 1148   2011-03-12 12:00:00       1        0           0        1  13.94
# ...                    ...     ...      ...         ...      ...    ...
# 4668   2011-11-07 14:00:00       4        0           1        1  22.96
# 9569   2012-10-03 02:00:00       4        0           1        2  25.42
# 4739   2011-11-10 13:00:00       4        0           1        3  14.76
# 10162  2012-11-08 20:00:00       4        0           1        1  15.58
# 10133  2012-11-07 14:00:00       4        0           1        2  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df_train, df_test = train_test_split(df, train_size=0.8, random_state=123)
df_test['temp'].max()
# Out:
# 39.36
